# %%
import pandas as pd

# %%
df = pd.read_excel("test_data/epsilon_20191104.xlsx")

# %%
df = df.rename(columns=lambda x: x.replace(" ", "_").lower())

# %%
df.head()
# Out:
#    fund_num                  fund_name  \
# 0   5100946  אפסילון (4A)  יתר
# 1   5100946  אפסילון (4A)  יתר
# 2   5100946  אפסילון (4A)  יתר
# 3   5100946  אפסילון (4A)  יתר
# 4   5100946  אפסילון (4A)  יתר
#
#                             instrument_name  instrument_type_num  \
# 0  המלט 1                                                      1
# 1  רימוני מר 1                                                 1
# 2  רקח 1                                                       1
# 3  איסתא  1ש''ח                                                1
# 4  בית שמש  1ש''ח                                              1
#
#   instrument_num  instrument_num_type  nominal_value_  fair_value  \
# 0        1080324                    1          4600.0   402960.00
# 1        1080456                    1         12181.0   767159.38
# 2        1081009                    1          5000.0   177000.00
# 3        1081074                    1          2500.0   198225.00
# ...

# %%
df[["ticker", "instrument_rate"]]
# Out:
#                       ticker  instrument_rate
# 0     HAML                               1.10
# 1     RIMO                               2.09
# 2     REKA                               0.48
# 3     ISTA                               0.54
# 4     BSEN                               2.20
# ...                      ...              ...
# 9994                                     0.00
# 9995                                     0.00
# 9996                                     0.00
# 9997                                     0.00
# 9998                                    96.42
#
# [9999 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['fund_num', 'fund_name', 'instrument_name', 'instrument_type_num',
#        'instrument_num', 'instrument_num_type', 'nominal_value_', 'fair_value',
#        'instrument_price', 'fair_value_fx', 'instrument_rate',
#        'lend_for_short', 'price_type', 'market_num', 'market_type',
#        'currency_num', 'exchange_rate\nexchange_rate\n', 'matur_bond',
#        'accrued_interest', 'ticker', 'country_num', 'rating',
#        'rating_agency_nוum', 'bank_num', 'datecode', 'row_num', 'total_row',
#        'manager_num'],
#       dtype='object')

# %%
df.ticker.value_counts()
# Out:
#                           3845
# WSPL.B1                     42
# MZT.B1                      40
# DSMN.N1                     37
# TSRN.B1                     37
#                           ...
# EWD                          1
# PSG.F117                     1
# KSM.F161                     1
# TCH.F100                     1
# HOD                          1
# Name: ticker, Length: 1169, dtype: int64
